# %% [markdown]
# # Week 2 Exercise 4
# ## Create a County (Community) Dataset
# - Each row is one county
# - Features (columns) are added from the following sources: AHRF, CHR, SVI
# - Features are engineered for:
#     - A couple of ratios (from the AHRF data)
#     - Community Health Needs Score (sum of z-scores for a number of features)

# %%
# Import needed modules
import pandas as pd
import sqlite3 as sql

# %%
# Connect to database (need the current working directory for systems that treat the local path as virtual)
import os
con = sql.connect(os.path.join(os.getcwd(), "synthea_and_county_ga.db"))

# %% [markdown]
# ## Dataframe: Each County as a Row

# %%
# Start the data frame with the counties (for the selected state)
df = pd.read_sql_query("""\
    select fips, state as state_abbr, name as county_name
    from us_counties_fips
    where state = 'GA'
""", con)

# %%
# Quick settings and clean-up
pd.options.display.max_columns = None   # Display all columns instead of only a selected set
pd.options.display.max_rows = None      # Display all rows
df = df.rename(columns=str.lower)       # Convert column names to lowercase
df = df.set_index('fips')               # Set the index to the id, rather than having pandas create an autocount index

# %%
# Check the dataframe
df.shape
# Out:
# (159, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159 entries, 13001 to 13321
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state_abbr   159 non-null    object
#  1   county_name  159 non-null    object
# dtypes: object(2)
# memory usage: 3.7+ KB

# %%
df.head(5)
# Out:
#       state_abbr      county_name
# fips
# 13001         GA   Appling County
# 13003         GA  Atkinson County
# 13005         GA     Bacon County
# 13007         GA     Baker County
# 13009         GA   Baldwin County

# %% [markdown]
# ## Add the AHRF data to our dataframe

# %%
# AHRF
df_query = pd.read_sql_query("""\
    select fips, 
        pop_est_2020,
        pop_den_2010,
        phys_pricare,
        phys_total,
        hosp_total,
        hosp_cah,
        hosp_with_ed,
        hosp_with_offcampus_ed,
        hosp_with_pedsed,
        hosp_with_traumactr,
        ed_visits
    from us_counties_ahrf_2021
""", con)

df_query = df_query.rename(columns=str.lower)
df_query = df_query.add_prefix('ahrf_')
df_query = df_query.set_index('ahrf_fips')

# %%
df = pd.merge(df, df_query, left_index=True, right_index=True, how='left')

# %%
df.head(5)
# Out:
#       state_abbr      county_name ahrf_pop_est_2020 ahrf_pop_den_2010  \
# fips
# 13001         GA   Appling County             18325                36
# 13003         GA  Atkinson County              8393              24.7
# 13005         GA     Bacon County             11036              42.9
# 13007         GA     Baker County              2971              10.1
# 13009         GA   Baldwin County             45099             177.3
#
#       ahrf_phys_pricare ahrf_phys_total ahrf_hosp_total ahrf_hosp_cah  \
# fips
# 13001                 6               9               1             0
# 13003                 0               0               0             0
# 13005                 7              10               1             1
# 13007                 0               0               0             0
# 13009                20              63               2             0
#
#       ahrf_hosp_with_ed ahrf_hosp_with_offcampus_ed ahrf_hosp_with_pedsed  \
# fips
# 13001                 0                           0                     0
# 13003                 0                           0                     0
# 13005                 0                           0                     0
# 13007                 0                           0                     0
# 13009                 1                           0                     0
#
#       ahrf_hosp_with_traumactr ahrf_ed_visits
# fips
# 13001                        0           7740
# 13003                        0              0
# 13005                        0           3759
# 13007                        0              0
# 13009                        0          30686

# %% [markdown]
# ## Add calcuated features (that are based on features from the AHRF data)

# %%
# Generate ratios

# ED Visits per captia
df['ahrf_ed_visits_per_capita'] = df['ahrf_ed_visits'] / df['ahrf_pop_est_2020']

# %%
# Primary care per 2000 people (should be about 1 primary care physician per 2000 people: see https://www.jabfm.org/content/jabfp/29/4/496.full.pdf)
df['ahrf_phys_pricare_per_2000'] = df['ahrf_phys_pricare'] / (df['ahrf_pop_est_2020'] / 2000)

# %%
# Rounding
df['ahrf_ed_visits_per_capita'] = df['ahrf_ed_visits_per_capita'].astype(float).round(2)
df['ahrf_phys_pricare_per_2000'] = df['ahrf_phys_pricare_per_2000'].astype(float).round(2)

# %%
df.head(5)
# Out:
#       state_abbr      county_name ahrf_pop_est_2020 ahrf_pop_den_2010  \
# fips
# 13001         GA   Appling County             18325                36
# 13003         GA  Atkinson County              8393              24.7
# 13005         GA     Bacon County             11036              42.9
# 13007         GA     Baker County              2971              10.1
# 13009         GA   Baldwin County             45099             177.3
#
#       ahrf_phys_pricare ahrf_phys_total ahrf_hosp_total ahrf_hosp_cah  \
# fips
# 13001                 6               9               1             0
# 13003                 0               0               0             0
# 13005                 7              10               1             1
# 13007                 0               0               0             0
# 13009                20              63               2             0
#
#       ahrf_hosp_with_ed ahrf_hosp_with_offcampus_ed ahrf_hosp_with_pedsed  \
# fips
# 13001                 0                           0                     0
# 13003                 0                           0                     0
# 13005                 0                           0                     0
# 13007                 0                           0                     0
# 13009                 1                           0                     0
#
#       ahrf_hosp_with_traumactr ahrf_ed_visits  ahrf_ed_visits_per_capita  \
# fips
# 13001                        0           7740                       0.42
# 13003                        0              0                       0.00
# 13005                        0           3759                       0.34
# 13007                        0              0                       0.00
# 13009                        0          30686                       0.68
#
#        ahrf_phys_pricare_per_2000
# fips
# 13001                        0.65
# 13003                        0.00
# 13005                        1.27
# 13007                        0.00
# 13009                        0.89

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159 entries, 13001 to 13321
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   state_abbr                   159 non-null    object
#  1   county_name                  159 non-null    object
#  2   ahrf_pop_est_2020            159 non-null    object
#  3   ahrf_pop_den_2010            159 non-null    object
#  4   ahrf_phys_pricare            159 non-null    object
#  5   ahrf_phys_total              159 non-null    object
#  6   ahrf_hosp_total              159 non-null    object
#  7   ahrf_hosp_cah                159 non-null    object
#  8   ahrf_hosp_with_ed            159 non-null    object
#  9   ahrf_hosp_with_offcampus_ed  159 non-null    object
#  10  ahrf_hosp_with_pedsed        159 non-null    object
#  11  ahrf_hosp_with_traumactr     159 non-null    object
#  12  ahrf_ed_visits               159 non-null    object
#  13  ahrf_ed_visits_per_capita    159 non-null    float64
#  14  ahrf_phys_pricare_per_2000   159 non-null    float64
# dtypes: float64(2), object(13)
# memory usage: 23.9+ KB

# %% [markdown]
# ## Add the CHR data to our dataframe

# %%
# County health rankings 
# Note: 1 is the healthiest quartile, 1 is the healthiest rank
# Source: https://www.countyhealthrankings.org/explore-health-rankings/our-methods/calculating-ranks
df_query = pd.read_sql_query("""\
    select fips, 
        healthoutcomes_rank, healthoutcomes_quartile,
        healthfactors_rank, healthfactors_quartile, 
        lengthoflife_rank, lengthoflife_quartile,
        qualityoflife_rank, qualityoflife_quartile,
        healthbehaviors_rank, healthbehaviors_quartile,
        clinicalcare_rank, clinicalcare_quartile,
        sesfactors_rank, sesfactors_quartile,
        physenv_rank, physenv_quartile
       from us_counties_chr_2022
""", con)

df_query = df_query.rename(columns=str.lower)
df_query = df_query.add_prefix('chr_')
df_query = df_query.set_index('chr_fips')

# %%
df = pd.merge(df, df_query, left_index=True, right_index=True, how='left')

# %%
df.head(5)
# Out:
#       state_abbr      county_name ahrf_pop_est_2020 ahrf_pop_den_2010  \
# fips
# 13001         GA   Appling County             18325                36
# 13003         GA  Atkinson County              8393              24.7
# 13005         GA     Bacon County             11036              42.9
# 13007         GA     Baker County              2971              10.1
# 13009         GA   Baldwin County             45099             177.3
#
#       ahrf_phys_pricare ahrf_phys_total ahrf_hosp_total ahrf_hosp_cah  \
# fips
# 13001                 6               9               1             0
# 13003                 0               0               0             0
# 13005                 7              10               1             1
# 13007                 0               0               0             0
# 13009                20              63               2             0
#
#       ahrf_hosp_with_ed ahrf_hosp_with_offcampus_ed ahrf_hosp_with_pedsed  \
# fips
# 13001                 0                           0                     0
# 13003                 0                           0                     0
# 13005                 0                           0                     0
# 13007                 0                           0                     0
# 13009                 1                           0                     0
#
#       ahrf_hosp_with_traumactr ahrf_ed_visits  ahrf_ed_visits_per_capita  \
# fips
# 13001                        0           7740                       0.42
# 13003                        0              0                       0.00
# 13005                        0           3759                       0.34
# 13007                        0              0                       0.00
# 13009                        0          30686                       0.68
#
#        ahrf_phys_pricare_per_2000 chr_healthoutcomes_rank  \
# fips
# 13001                        0.65                     113
# 13003                        0.00                     112
# 13005                        1.27                     139
# 13007                        0.00                      77
# 13009                        0.89                      91
#
#       chr_healthoutcomes_quartile chr_healthfactors_rank  \
# fips
# 13001                           3                    118
# 13003                           3                    137
# 13005                           4                    123
# 13007                           2                    128
# 13009                           3                     95
#
#       chr_healthfactors_quartile chr_lengthoflife_rank  \
# fips
# 13001                          3                   108
# 13003                          4                   122
# 13005                          4                   144
# 13007                          4                    74
# 13009                          3                    98
#
#       chr_lengthoflife_quartile chr_qualityoflife_rank  \
# fips
# 13001                         3                    116
# 13003                         4                    108
# 13005                         4                    115
# 13007                         2                     82
# 13009                         3                     84
#
#       chr_qualityoflife_quartile chr_healthbehaviors_rank  \
# fips
# 13001                          3                      131
# 13003                          3                      130
# 13005                          3                      118
# 13007                          3                      104
# 13009                          3                       71
#
#       chr_healthbehaviors_quartile chr_clinicalcare_rank  \
# fips
# 13001                            4                   152
# 13003                            4                   154
# 13005                            3                   159
# 13007                            3                   109
# 13009                            2                    59
#
#       chr_clinicalcare_quartile chr_sesfactors_rank chr_sesfactors_quartile  \
# fips
# 13001                         4                  79                       2
# 13003                         4                 115                       3
# 13005                         4                  92                       3
# 13007                         3                 141                       4
# 13009                         2                 110                       3
#
#       chr_physenv_rank chr_physenv_quartile
# fips
# 13001               14                    1
# 13003               15                    1
# 13005               22                    1
# 13007              104                    3
# 13009              159                    4

# %% [markdown]
# ## Add the SVI data to our dataframe

# %%
# Social Vulnerability Index (SVI)
df_query = pd.read_sql_query("""\
    select fips,
        svi_perc,
        svi_ses_perc,
        svi_hcd_perc,
        svi_msl_perc,
        svi_htt_perc
    from us_counties_svi_2018
""", con)

df_query = df_query.rename(columns=str.lower)
df_query = df_query.set_index('fips')

# %%
df = pd.merge(df, df_query, left_index=True, right_index=True, how='left')

# %%
df.head(5)
# Out:
#       state_abbr      county_name ahrf_pop_est_2020 ahrf_pop_den_2010  \
# fips
# 13001         GA   Appling County             18325                36
# 13003         GA  Atkinson County              8393              24.7
# 13005         GA     Bacon County             11036              42.9
# 13007         GA     Baker County              2971              10.1
# 13009         GA   Baldwin County             45099             177.3
#
#       ahrf_phys_pricare ahrf_phys_total ahrf_hosp_total ahrf_hosp_cah  \
# fips
# 13001                 6               9               1             0
# 13003                 0               0               0             0
# 13005                 7              10               1             1
# 13007                 0               0               0             0
# 13009                20              63               2             0
#
#       ahrf_hosp_with_ed ahrf_hosp_with_offcampus_ed ahrf_hosp_with_pedsed  \
# fips
# 13001                 0                           0                     0
# 13003                 0                           0                     0
# 13005                 0                           0                     0
# 13007                 0                           0                     0
# 13009                 1                           0                     0
#
#       ahrf_hosp_with_traumactr ahrf_ed_visits  ahrf_ed_visits_per_capita  \
# fips
# 13001                        0           7740                       0.42
# 13003                        0              0                       0.00
# 13005                        0           3759                       0.34
# 13007                        0              0                       0.00
# 13009                        0          30686                       0.68
#
#        ahrf_phys_pricare_per_2000 chr_healthoutcomes_rank  \
# fips
# 13001                        0.65                     113
# 13003                        0.00                     112
# 13005                        1.27                     139
# 13007                        0.00                      77
# 13009                        0.89                      91
#
#       chr_healthoutcomes_quartile chr_healthfactors_rank  \
# fips
# 13001                           3                    118
# 13003                           3                    137
# 13005                           4                    123
# 13007                           2                    128
# 13009                           3                     95
#
#       chr_healthfactors_quartile chr_lengthoflife_rank  \
# fips
# 13001                          3                   108
# 13003                          4                   122
# 13005                          4                   144
# 13007                          4                    74
# 13009                          3                    98
#
#       chr_lengthoflife_quartile chr_qualityoflife_rank  \
# fips
# 13001                         3                    116
# 13003                         4                    108
# 13005                         4                    115
# 13007                         2                     82
# 13009                         3                     84
#
#       chr_qualityoflife_quartile chr_healthbehaviors_rank  \
# fips
# 13001                          3                      131
# 13003                          3                      130
# 13005                          3                      118
# 13007                          3                      104
# 13009                          3                       71
#
#       chr_healthbehaviors_quartile chr_clinicalcare_rank  \
# fips
# 13001                            4                   152
# 13003                            4                   154
# 13005                            3                   159
# 13007                            3                   109
# 13009                            2                    59
#
#       chr_clinicalcare_quartile chr_sesfactors_rank chr_sesfactors_quartile  \
# fips
# 13001                         4                  79                       2
# 13003                         4                 115                       3
# 13005                         4                  92                       3
# 13007                         3                 141                       4
# 13009                         2                 110                       3
#
#       chr_physenv_rank chr_physenv_quartile  svi_perc  svi_ses_perc  \
# fips
# 13001               14                    1    0.9669        0.8818
# 13003               15                    1    0.9615        0.9790
# 13005               22                    1    0.9389        0.8408
# 13007              104                    3    0.7424        0.7290
# 13009              159                    4    0.8666        0.9131
#
#        svi_hcd_perc  svi_msl_perc  svi_htt_perc
# fips
# 13001        0.9605        0.8153        0.8940
# 13003        0.7803        0.9395        0.7042
# 13005        0.9535        0.7978        0.8204
# 13007        0.5782        0.6759        0.6068
# 13009        0.1576        0.7084        0.9494

# %% [markdown]
# ## Add some provider data from Synthea
# - Note: We don't need to do "organizations" from Synthea as Synthea only has one provider per organization, which makes the counts and utilizations averages per county the same between organizations and providers
# - Note: Did not include 'utilization' as this is for all time and is relatively confusing

# %%
df_query = pd.read_sql_query("""\
    select uscc.county_fips, COUNT(p.Id) as provider_count
    from providers p
    inner join us_states_cities_counties uscc on p.state = uscc.state_id COLLATE NOCASE and p.city = uscc.city COLLATE NOCASE
    group by uscc.county_fips
""", con)

df_query = df_query.rename(columns=str.lower)
df_query = df_query.add_prefix('syn_')
df_query = df_query.set_index('syn_county_fips')

# %%
df = pd.merge(df, df_query, left_index=True, right_index=True, how='left')

# %%
df['syn_provider_count'] = df['syn_provider_count'].fillna(0)
df['syn_provider_count'] = df['syn_provider_count'].astype('int64')

# %%
df.head(5)
# Out:
#       state_abbr      county_name ahrf_pop_est_2020 ahrf_pop_den_2010  \
# fips
# 13001         GA   Appling County             18325                36
# 13003         GA  Atkinson County              8393              24.7
# 13005         GA     Bacon County             11036              42.9
# 13007         GA     Baker County              2971              10.1
# 13009         GA   Baldwin County             45099             177.3
#
#       ahrf_phys_pricare ahrf_phys_total ahrf_hosp_total ahrf_hosp_cah  \
# fips
# 13001                 6               9               1             0
# 13003                 0               0               0             0
# 13005                 7              10               1             1
# 13007                 0               0               0             0
# 13009                20              63               2             0
#
#       ahrf_hosp_with_ed ahrf_hosp_with_offcampus_ed ahrf_hosp_with_pedsed  \
# fips
# 13001                 0                           0                     0
# 13003                 0                           0                     0
# 13005                 0                           0                     0
# 13007                 0                           0                     0
# 13009                 1                           0                     0
#
#       ahrf_hosp_with_traumactr ahrf_ed_visits  ahrf_ed_visits_per_capita  \
# fips
# 13001                        0           7740                       0.42
# 13003                        0              0                       0.00
# 13005                        0           3759                       0.34
# 13007                        0              0                       0.00
# 13009                        0          30686                       0.68
#
#        ahrf_phys_pricare_per_2000 chr_healthoutcomes_rank  \
# fips
# 13001                        0.65                     113
# 13003                        0.00                     112
# 13005                        1.27                     139
# 13007                        0.00                      77
# 13009                        0.89                      91
#
#       chr_healthoutcomes_quartile chr_healthfactors_rank  \
# fips
# 13001                           3                    118
# 13003                           3                    137
# 13005                           4                    123
# 13007                           2                    128
# 13009                           3                     95
#
#       chr_healthfactors_quartile chr_lengthoflife_rank  \
# fips
# 13001                          3                   108
# 13003                          4                   122
# 13005                          4                   144
# 13007                          4                    74
# 13009                          3                    98
#
#       chr_lengthoflife_quartile chr_qualityoflife_rank  \
# fips
# 13001                         3                    116
# 13003                         4                    108
# 13005                         4                    115
# 13007                         2                     82
# 13009                         3                     84
#
#       chr_qualityoflife_quartile chr_healthbehaviors_rank  \
# fips
# 13001                          3                      131
# 13003                          3                      130
# 13005                          3                      118
# 13007                          3                      104
# 13009                          3                       71
#
#       chr_healthbehaviors_quartile chr_clinicalcare_rank  \
# fips
# 13001                            4                   152
# 13003                            4                   154
# 13005                            3                   159
# 13007                            3                   109
# 13009                            2                    59
#
#       chr_clinicalcare_quartile chr_sesfactors_rank chr_sesfactors_quartile  \
# fips
# 13001                         4                  79                       2
# 13003                         4                 115                       3
# 13005                         4                  92                       3
# 13007                         3                 141                       4
# 13009                         2                 110                       3
#
#       chr_physenv_rank chr_physenv_quartile  svi_perc  svi_ses_perc  \
# fips
# 13001               14                    1    0.9669        0.8818
# 13003               15                    1    0.9615        0.9790
# 13005               22                    1    0.9389        0.8408
# 13007              104                    3    0.7424        0.7290
# 13009              159                    4    0.8666        0.9131
#
#        svi_hcd_perc  svi_msl_perc  svi_htt_perc  syn_provider_count
# fips
# 13001        0.9605        0.8153        0.8940                  11
# 13003        0.7803        0.9395        0.7042                   3
# 13005        0.9535        0.7978        0.8204                   7
# 13007        0.5782        0.6759        0.6068                   1
# 13009        0.1576        0.7084        0.9494                  18

# %% [markdown]
# ## Generate a "Community Health Needs Score" (from some of the existing features)

# %%
# Convert all <object> columns that are numeric to a numeric datatype
cols = df.columns.drop(['state_abbr', 'county_name']) # don't want string cols
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
# Change all numeric columns to their respective z-scores
import scipy.stats as stats
df_zscore = df.select_dtypes(include='number').apply(stats.zscore)

# %%
# For comparison, what is the mean and std of one of the columns?
temp_mean = df['ahrf_pop_est_2020'].mean()
temp_std = df['ahrf_pop_est_2020'].std()
print(f'The mean of ahrf_pop_est_2020 is {temp_mean} and the std is {temp_std}')
# Out:
# The mean of ahrf_pop_est_2020 is 67358.59748427673 and the std is 146050.71327830883

# %%
df_zscore.head(5)
# Out:
#        ahrf_pop_est_2020  ahrf_pop_den_2010  ahrf_phys_pricare  \
# fips
# 13001          -0.336791          -0.417278          -0.286879
# 13003          -0.405009          -0.447199          -0.331293
# 13005          -0.386856          -0.399007          -0.279476
# 13007          -0.442251          -0.485859          -0.331293
# 13009          -0.152892          -0.043126          -0.183245
#
#        ahrf_phys_total  ahrf_hosp_total  ahrf_hosp_cah  ahrf_hosp_with_ed  \
# fips
# 13001        -0.245780        -0.049265      -0.492125          -0.556094
# 13003        -0.260038        -0.651814      -0.492125          -0.556094
# 13005        -0.244196        -0.049265       2.032002          -0.556094
# 13007        -0.260038        -0.651814      -0.492125          -0.556094
# 13009        -0.160233         0.553284      -0.492125           0.577482
#
#        ahrf_hosp_with_offcampus_ed  ahrf_hosp_with_pedsed  \
# fips
# 13001                    -0.079556              -0.217786
# 13003                    -0.079556              -0.217786
# 13005                    -0.079556              -0.217786
# 13007                    -0.079556              -0.217786
# 13009                    -0.079556              -0.217786
#
#        ahrf_hosp_with_traumactr  ahrf_ed_visits  ahrf_ed_visits_per_capita  \
# fips
# 13001                 -0.280009       -0.334818                   0.105220
# 13003                 -0.280009       -0.456792                  -0.869338
# 13005                 -0.280009       -0.397555                  -0.080411
# 13007                 -0.280009       -0.456792                  -0.869338
# 13009                 -0.280009        0.026785                   0.708517
#
#        ahrf_phys_pricare_per_2000  chr_healthoutcomes_rank  \
# fips
# 13001                   -0.308396                 0.718979
# 13003                   -1.395830                 0.697191
# 13005                    0.728849                 1.285447
# 13007                   -1.395830                -0.065362
# 13009                    0.093118                 0.239660
#
#        chr_healthoutcomes_quartile  chr_healthfactors_rank  \
# fips
# 13001                     0.448900                0.827915
# 13003                     0.448900                1.241872
# 13005                     1.341089                0.936851
# 13007                    -0.443289                1.045787
# 13009                     0.448900                0.326809
#
#        chr_healthfactors_quartile  chr_lengthoflife_rank  \
# fips
# 13001                    0.448900               0.611985
# 13003                    1.341089               0.916950
# 13005                    1.341089               1.396181
# 13007                    1.341089              -0.128644
# 13009                    0.448900               0.394153
#
#        chr_lengthoflife_quartile  chr_qualityoflife_rank  \
# fips
# 13001                   0.448900                0.784340
# 13003                   1.341089                0.610043
# 13005                   1.341089                0.762553
# 13007                  -0.443289                0.043574
# 13009                   0.448900                0.087149
#
#        chr_qualityoflife_quartile  chr_healthbehaviors_rank  \
# fips
# 13001                      0.4489                  1.111149
# 13003                      0.4489                  1.089362
# 13005                      0.4489                  0.827915
# 13007                      0.4489                  0.522894
# 13009                      0.4489                 -0.196085
#
#        chr_healthbehaviors_quartile  chr_clinicalcare_rank  \
# fips
# 13001                      1.341089               1.568681
# 13003                      1.341089               1.612255
# 13005                      0.448900               1.721191
# 13007                      0.448900               0.631830
# 13009                     -0.443289              -0.457532
#
#        chr_clinicalcare_quartile  chr_sesfactors_rank  \
# fips
# 13001                   1.341089            -0.021787
# 13003                   1.341089             0.762553
# 13005                   1.341089             0.261447
# 13007                   0.448900             1.329021
# 13009                  -0.443289             0.653617
#
#        chr_sesfactors_quartile  chr_physenv_rank  chr_physenv_quartile  \
# fips
# 13001                -0.443289         -1.437957             -1.335478
# 13003                 0.448900         -1.416170             -1.335478
# 13005                 0.448900         -1.263660             -1.335478
# 13007                 1.341089          0.522894              0.448900
# 13009                 0.448900          1.721191              1.341089
#
#        svi_perc  svi_ses_perc  svi_hcd_perc  svi_msl_perc  svi_htt_perc  \
# fips
# 13001  1.011171      0.669981      1.351231      0.770054      0.945364
# 13003  0.990082      1.092072      0.718766      1.402941      0.344730
# 13005  0.901820      0.491938      1.326662      0.680879      0.712452
# 13007  0.134407      0.006445      0.009437      0.059713      0.036502
# 13009  0.619459      0.805901     -1.466783      0.225323      1.120680
#
#        syn_provider_count
# fips
# 13001           -0.122098
# 13003           -0.417925
# 13005           -0.270011
# 13007           -0.491881
# 13009            0.136750

# %%
# Community needs score (higher score = more needs)
# Variables where positive is better are reversed coded
df['comm_health_needs_score'] = (-1 * df_zscore['ahrf_phys_pricare_per_2000']) + df_zscore['ahrf_ed_visits_per_capita'] + df_zscore['chr_healthoutcomes_rank'] + df_zscore['chr_healthfactors_rank'] + df_zscore['svi_perc']

# %%
df['comm_health_needs_score'] = df['comm_health_needs_score'].round(2)

# %%
df.head(5)
# Out:
#       state_abbr      county_name  ahrf_pop_est_2020  ahrf_pop_den_2010  \
# fips
# 13001         GA   Appling County            18325.0               36.0
# 13003         GA  Atkinson County             8393.0               24.7
# 13005         GA     Bacon County            11036.0               42.9
# 13007         GA     Baker County             2971.0               10.1
# 13009         GA   Baldwin County            45099.0              177.3
#
#        ahrf_phys_pricare  ahrf_phys_total  ahrf_hosp_total  ahrf_hosp_cah  \
# fips
# 13001                6.0              9.0              1.0            0.0
# 13003                0.0              0.0              0.0            0.0
# 13005                7.0             10.0              1.0            1.0
# 13007                0.0              0.0              0.0            0.0
# 13009               20.0             63.0              2.0            0.0
#
#        ahrf_hosp_with_ed  ahrf_hosp_with_offcampus_ed  ahrf_hosp_with_pedsed  \
# fips
# 13001                0.0                          0.0                    0.0
# 13003                0.0                          0.0                    0.0
# 13005                0.0                          0.0                    0.0
# 13007                0.0                          0.0                    0.0
# 13009                1.0                          0.0                    0.0
#
#        ahrf_hosp_with_traumactr  ahrf_ed_visits  ahrf_ed_visits_per_capita  \
# fips
# 13001                       0.0          7740.0                       0.42
# 13003                       0.0             0.0                       0.00
# 13005                       0.0          3759.0                       0.34
# 13007                       0.0             0.0                       0.00
# 13009                       0.0         30686.0                       0.68
#
#        ahrf_phys_pricare_per_2000  chr_healthoutcomes_rank  \
# fips
# 13001                        0.65                    113.0
# 13003                        0.00                    112.0
# 13005                        1.27                    139.0
# 13007                        0.00                     77.0
# 13009                        0.89                     91.0
#
#        chr_healthoutcomes_quartile  chr_healthfactors_rank  \
# fips
# 13001                          3.0                   118.0
# 13003                          3.0                   137.0
# 13005                          4.0                   123.0
# 13007                          2.0                   128.0
# 13009                          3.0                    95.0
#
#        chr_healthfactors_quartile  chr_lengthoflife_rank  \
# fips
# 13001                         3.0                  108.0
# 13003                         4.0                  122.0
# 13005                         4.0                  144.0
# 13007                         4.0                   74.0
# 13009                         3.0                   98.0
#
#        chr_lengthoflife_quartile  chr_qualityoflife_rank  \
# fips
# 13001                        3.0                   116.0
# 13003                        4.0                   108.0
# 13005                        4.0                   115.0
# 13007                        2.0                    82.0
# 13009                        3.0                    84.0
#
#        chr_qualityoflife_quartile  chr_healthbehaviors_rank  \
# fips
# 13001                         3.0                     131.0
# 13003                         3.0                     130.0
# 13005                         3.0                     118.0
# 13007                         3.0                     104.0
# 13009                         3.0                      71.0
#
#        chr_healthbehaviors_quartile  chr_clinicalcare_rank  \
# fips
# 13001                           4.0                  152.0
# 13003                           4.0                  154.0
# 13005                           3.0                  159.0
# 13007                           3.0                  109.0
# 13009                           2.0                   59.0
#
#        chr_clinicalcare_quartile  chr_sesfactors_rank  \
# fips
# 13001                        4.0                 79.0
# 13003                        4.0                115.0
# 13005                        4.0                 92.0
# 13007                        3.0                141.0
# 13009                        2.0                110.0
#
#        chr_sesfactors_quartile  chr_physenv_rank  chr_physenv_quartile  \
# fips
# 13001                      2.0              14.0                   1.0
# 13003                      3.0              15.0                   1.0
# 13005                      3.0              22.0                   1.0
# 13007                      4.0             104.0                   3.0
# 13009                      3.0             159.0                   4.0
#
#        svi_perc  svi_ses_perc  svi_hcd_perc  svi_msl_perc  svi_htt_perc  \
# fips
# 13001    0.9669        0.8818        0.9605        0.8153        0.8940
# 13003    0.9615        0.9790        0.7803        0.9395        0.7042
# 13005    0.9389        0.8408        0.9535        0.7978        0.8204
# 13007    0.7424        0.7290        0.5782        0.6759        0.6068
# 13009    0.8666        0.9131        0.1576        0.7084        0.9494
#
#        syn_provider_count  comm_health_needs_score
# fips
# 13001                11.0                     2.97
# 13003                 3.0                     3.46
# 13005                 7.0                     2.31
# 13007                 1.0                     1.64
# 13009                18.0                     1.80

# %% [markdown]
# ## Output to CSV (for use in Tableau)

# %%
df.to_csv('w2e4_county_dataset.csv')
